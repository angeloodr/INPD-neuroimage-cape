# %%
#In windows, run anaconda prompt, and go to BIDS folder. Run jupyter notebook
#MAIN CODE TO CALCULATE SEED BASED VOXEL IN BATCH MODE FOLLOWING BIDS AND fMRIPREP

import numpy as np
import os, sys
import bids
import nibabel as nib
from scipy.stats import pearsonr
import statsmodels.api as sm
from nilearn import plotting as nplot
from nilearn import image as nimg
from nilearn.image import resample_to_img
import matplotlib.pyplot as plt
import argparse
import pandas as pd
#%%
##
def parse():

        options = argparse.ArgumentParser(description="Run 1st level analysis. Created by ...")
        options.add_argument('-p', '--participants', nargs='+',dest="participants", action='store', type=str, required=False,
                            help='id of subject or list of subjects')
        options.set_defaults(participants=None)
        options.add_argument('-w', '--workdir',dest="workdir", action='store', type=str, required=False,
                            help='the work directory for the project')
        options.set_defaults(workdir=os.environ["ROOTDIR"])
        options.add_argument('-b', '--bidsdir',dest="rawdata", action='store', type=str, required=False,
                            help='the work directory for the project')
        options.set_defaults(rawdata=os.path.join(os.environ["ROOTDIR"],"BIDS"))
        options.add_argument('-d', '--derivatives',dest="derivatives", action='store', type=str, required=True,
                            help='path to fMRIprep directory')
        options.add_argument('-o', '--outputs',dest="output", action='store', type=str, required=True,
                            help='path to fMRIprep directory')
        #print(options.parse_args())

        return options.parse_args()

#%%
def main ():
    os.environ["ROOTDIR"] = r'C:\Users\angel\Documents\INPD_neuroimages_CAPE'  # seth path
    rootdir = os.environ["ROOTDIR"]
    if hasattr(sys, "ps1"):
        options = {}
        workdir = os.environ["ROOTDIR"]
        rawdata = os.path.join(workdir,"BIDS")
        derivat = os.path.join(workdir,"BIDS","derivatives","fmriprep")
        output  = os.path.join(workdir,"BIDS","derivatives","BOLD_ROI")
        masks = os.path.join(workdir,"analisys_code","atlas")
        participants = []

    else :
        options = parse()
        participants = options.participants
        workdir = options.workdir
        rawdata = options.rawdata
        derivat = options.derivatives
        output  = options.output
        script_path = os.path.dirname(__file__)
        masks = os.path.join(script_path,"masks")

    with open("ROI_names.txt", "r", encoding="utf-16") as file:
        seednames = [line.strip() for line in file if line.strip()]

    print('Rawdata: ', rawdata)

    bidslayout = bids.BIDSLayout(derivat,derivatives=True, validate = False) #With validate = True it doesn't find any subjects

    if not participants:
        participants = bidslayout.get_subjects()
    for i in  participants:
        print("Subject: ", i)
        i = i.replace("sub-", "")
        for ses in bidslayout.get_sessions(subject=i):
            print("Session: ", ses)
            #for multi-echo files, apply transform to standard space
            for r in bidslayout.get_runs(subject=i, session=ses):
                print("Run:", r)
                filesrest = bidslayout.get(subject=i,
                                 session=ses,
                                 run=r,
                                 extension=".nii.gz",
                                 suffix="bold",
                                 space="MNI152NLin2009cAsym",
                                 #regex_search=True,
                                 #invalid_filters="allow"
                                 )

                print("Filerest:", filesrest)
                if len(filesrest)>1:
                    print(f"More than one file match bold filters. Subject {i}, ses {ses}, run {r}")
                    continue
                elif len(filesrest)<1:
                    print(f"No file match bold filters. Subject {i}, ses {ses}, run {r}")
                    continue
                bold = filesrest[0]

                filesbrainmask = bidslayout.get(subject=i,
                                  session=ses,
                                  run=r,
                                  task='rest',
                                  extension=".nii.gz",
                                  suffix="mask",
                                  space="MNI152NLin2009cAsym",
                                  #regex_search=True,
                                  invalid_filters="allow"
                                  )
                print("Brain_Mask:", filesbrainmask)
                if len(filesbrainmask)>1:
                    print(f"More than one file match brainmask filters. Subject {i}, ses {ses}, run {r}")
                    continue
                brainmask = filesbrainmask[0]


                filesanat = bidslayout.get(subject=i,
                                 session=ses,
                                 run=r,
                                 extension=".nii.gz",
                                 suffix="T1w",
                                 #desc="preproc",
                                 space="MNI152NLin2009cAsym",
                                 #regex_search=True,
                                 invalid_filters="allow"
                                 )

                print(f"Anat: {filesanat} ")
                if len(filesrest)>1:
                    print(f"More than one file match anat filters. Subject {i}, ses {ses}, run {r}")
                    continue
                
                #Load Confounds
                confounds_ents = {}
                confounds_ents["subject"] = bold.entities['subject']
                confounds_ents["session"] = bold.entities['session']
                #confounds_ents["acquisition"] = bold.entities['acquisition']
                confounds_ents["run"] = bold.entities['run']
                confounds_ents["task"] = bold.entities['TaskName']
                #confounds_ents['desc'] = "confounds"
                confounds_ents['suffix'] = "timeseries"
                confounds_ents['extension'] = ".tsv"
                confounds = bidslayout.get(return_type='file', **confounds_ents, invalid_filters="allow")[0]
                allconfounds_df = pd.read_csv(confounds, sep='\t')

                melodic_ents = confounds_ents
                melodic_ents['suffix'] = "mixing"
                melodic = bidslayout.get(return_type='file', **melodic_ents, invalid_filters="allow")[0]
                melodic_df = pd.read_csv(melodic, sep='\t')

                aroma_noise = confounds_ents
                aroma_noise['suffix'] = "AROMAnoiseICs"
                aroma_noise['extension'] = ".csv"
                aroma_noise = bidslayout.get(return_type='file', **aroma_noise, invalid_filters="allow")[0]
                aroma_noise_idx = np.genfromtxt(aroma_noise, delimiter=',').astype(int)

                aroma_conf = melodic_df.iloc[:,aroma_noise_idx-1]

                conf_index= ['csf', 'white_matter','cosine00','cosine01','cosine02','cosine03']
                confounds_df = allconfounds_df[conf_index]

                #DROP 4 initial volumes and generate confounds matrix
                drop_confound_df = confounds_df.loc[4:].values #from confounds
                drop_aroma_conf = aroma_conf.loc[3:].values #it has one less time point

                # try:
                my_confounds = np.concatenate((drop_confound_df, drop_aroma_conf), axis=1)

                #DROP 4 volumes from bold data
                raw_func_img = nimg.load_img(bold)
                func_img = raw_func_img.slicer[:,:,:,4:]
                dim4d = func_img.shape
                N = dim4d[-1]  # number of time points

                # #reshape into 2d
                func_2d = func_img.get_fdata().reshape(-1, func_img.shape[-1]).T

                # pre-allocate space for seeds' time series
                TS_seeds = np.empty((N, len(seednames)))
                # Input new nifti for seeds
                # Compute SEEDs TS
                for k in range(len(seednames)):
                    print('----- TS Seed:', seednames[k], '-----')

                    seed = os.path.join(masks, seednames[k])
                    #load seed image
                    Vseed_img = nib.load(seed)
                    Vseed = Vseed_img.get_fdata().reshape(func_2d.shape[-1])

                    #for each time point, compute mean of voxels in which seed==1
                    for vol in range(N):
                        Vaux = func_2d[vol, :]
                        TS_seeds[vol, k] = np.mean(Vaux[Vseed == 1])
                        del Vaux

                    del Vseed

                '''Just to have it clear, the TS_seeds have the following structure:
                TS_seeds = [PARCELATIONS_ROIS, TSseed1, TSseed2, TSseed3, TSseed4, TSseed5, TSseed6]
                '''

                #--------- 1st Level Analysis: -------------------------------------------
                print('First level analysis -----')
                print('TS_ROI = b0 + b_j*TSseed_j + CSF + WM + cosines + AROMA_noiseICs')
                t_map = np.zeros((len(seednames[:-6]), len(seednames[-6:])))  # t[ROIs,seeds]

                # sinal = np.reshape(TS_seeds[:,-6:], (len(TS_seeds[:,-6:]),1))
                # design_matrix = np.concatenate((sinal,my_confounds), axis=1)
                # design_matrix = sm.add_constant(design_matrix)
                # print('Design matrix shape:', design_matrix.shape)

                for roi in range(len(seednames[:-6])):
                    for seed in range(len(seednames[-6:])):
                        sinal = np.reshape(TS_seeds[:,seed], (len(TS_seeds[:,seed]),1))
                        design_matrix = np.concatenate((sinal,my_confounds), axis=1)
                        design_matrix = sm.add_constant(design_matrix)
                        print('Design matrix shape:', design_matrix.shape)

                        # Fit the multiple linear regression model
                        model = sm.OLS(TS_seeds[:, roi], design_matrix)
                        results = model.fit()

                        print('getting t-values for ROI:', seednames[roi], 'and seed:', seednames[(-1-seed)])
                        # Get the t-values
                        t_values = results.tvalues
                        t_map[roi, :] = t_values[1:7] #t_values[0] is the constant and the others is confunds
                # ------------------------------------------------------------------------
                # addinig in the first line of t_map matrix the seed names
                # t_map = np.vstack((seednames[-6:], t_map))

                tmap_metadata = {
                    'task': 'rest',
                    'suffix': 'tstat',
                    'extension': '.txt',
                    'run': str(r),
                    'session': str(ses),
                    'subject': 'sub-'+i,
                    'space': 'MNI152NLin2009cAsym',
                    'seed': 'SeedtoROI'
                }

                # Save each tmap as a nifti file
                filepath = os.path.join(output,tmap_metadata["subject"],"ses-"+tmap_metadata['session'],"func")
                filename = tmap_metadata["subject"] + "_" + \
                            "ses-"+tmap_metadata['session'] + "_" + \
                            "task-"+tmap_metadata['task'] + "_" + \
                            "run-"+tmap_metadata['run'] + "_" + \
                            "space-"+tmap_metadata['space'] + "_" + \
                            "seed-"+tmap_metadata['seed'] + "_" + \
                            tmap_metadata["suffix"] + \
                            tmap_metadata["extension"]

                folder_subj=os.path.join(output,tmap_metadata["subject"])
                if not os.path.exists(folder_subj):
                    os.makedirs(folder_subj)

                if not os.path.exists(filepath):
                        os.makedirs(filepath)
                
                header = ' '.join(seednames[-6:])
                np.savetxt(os.path.join(filepath, filename), t_map, delimiter=' ', header=header, comments='')

                print('\t\t ----- Finished subject', i, ' Sess: ' ,ses,' Run: ',r,' ----')
                    
                # except:
                #     print('\t\t ----- ERRO NO SUJEITO', i, ' Sess: ' ,ses,' Run: ',r,' ----')
        
if __name__ == '__main__':
    main()
# Out:
# Rawdata:  C:\Users\angel\Documents\INPD_neuroimages_CAPE\BIDS
# c:\Users\angel\Documents\INPD_neuroimages_CAPE\.venv_fmriINPD\Lib\site-packages\bids\layout\layout.py:516: UserWarning: Derivative indexing was requested, but no valid datasets were found in the specified locations ([WindowsPath('C:/Users/angel/Documents/INPD_neuroimages_CAPE/BIDS/derivatives/fmriprep/derivatives')]). Note that all BIDS-Derivatives datasets must meet all the requirements for BIDS-Raw datasets (a common problem is to fail to include a 'dataset_description.json' file in derivatives datasets).
ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02298, ses 3, run 1
# Subject:  02300
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02300, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02300, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02300, ses 3, run 1
# Subject:  02304
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02304, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02304, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02304, ses 3, run 1
# Subject:  02305
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02305, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02305, ses 2, run 1
# Subject:  02307
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02307, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02307, ses 3, run 1
# Subject:  02309
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02309, ses 1, run 1
# Subject:  02312
# Session:  1
# Run: 2
# Filerest: []
# No file match bold filters. Subject 02312, ses 1, run 2
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02312, ses 2, run 1
# Subject:  02315
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02315, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02315, ses 3, run 1
# Subject:  02316
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02316, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02316, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02316, ses 3, run 1
# Subject:  02317
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02317, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02317, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02317, ses 3, run 1
# Subject:  02325
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02325, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02325, ses 3, run 1
# Subject:  02330
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02330, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02330, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02330, ses 3, run 1
# Subject:  02332
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02332, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02332, ses 3, run 1
# Subject:  02333
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02333, ses 1, run 1
# Session:  2
# Run: 2
# Filerest: []
# No file match bold filters. Subject 02333, ses 2, run 2
# Subject:  02336
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02336, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02336, ses 3, run 1
# Subject:  02340
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02340, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02340, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02340, ses 3, run 1
# Subject:  02344
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02344, ses 1, run 1
# Subject:  02345
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02345, ses 1, run 1
# Subject:  02353
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02353, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02353, ses 2, run 1
# Subject:  02354
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02354, ses 2, run 1
# Subject:  02364
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02364, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02364, ses 2, run 1
# Subject:  02367
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02367, ses 2, run 1
# Subject:  02370
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02370, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02370, ses 3, run 1
# Subject:  02371
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02371, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02371, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02371, ses 3, run 1
# Subject:  02375
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02375, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02375, ses 2, run 1
# Subject:  02377
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02377, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02377, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02377, ses 3, run 1
# Subject:  02378
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02378, ses 1, run 1
# Subject:  02381
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02381, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02381, ses 3, run 1
# Subject:  02384
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02384, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02384, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02384, ses 3, run 1
# Subject:  02387
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02387, ses 2, run 1
# Subject:  02388
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02388, ses 2, run 1
# Subject:  02393
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02393, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02393, ses 3, run 1
# Subject:  02396
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02396, ses 1, run 1
# Subject:  02399
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02399, ses 3, run 1
# Subject:  02403
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02403, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02403, ses 3, run 1
# Subject:  02406
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02406, ses 2, run 1
# Subject:  02412
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02412, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02412, ses 2, run 1
# Subject:  02414
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02414, ses 1, run 1
# Subject:  02416
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02416, ses 1, run 1
# Subject:  02417
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02417, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02417, ses 2, run 1
# Subject:  02420
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02420, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02420, ses 3, run 1
# Subject:  02421
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02421, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02421, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02421, ses 3, run 1
# Subject:  02423
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02423, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02423, ses 2, run 1
# Subject:  02425
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02425, ses 1, run 1
# Subject:  02440
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02440, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02440, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02440, ses 3, run 1
# Subject:  02447
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02447, ses 1, run 1
# Subject:  02450
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02450, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02450, ses 3, run 1
# Run: 2
# Filerest: []
# No file match bold filters. Subject 02450, ses 3, run 2
# Subject:  02452
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02452, ses 1, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02452, ses 3, run 1
# Subject:  02454
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02454, ses 3, run 1
# Subject:  02458
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02458, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02458, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02458, ses 3, run 1
# Subject:  02460
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02460, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02460, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02460, ses 3, run 1
# Subject:  02461
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02461, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02461, ses 2, run 1
# Subject:  02466
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02466, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02466, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02466, ses 3, run 1
# Subject:  02473
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02473, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02473, ses 2, run 1
# Subject:  02476
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02476, ses 1, run 1
# Session:  2
# Run: 2
# Filerest: []
# No file match bold filters. Subject 02476, ses 2, run 2
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02476, ses 3, run 1
# Subject:  02480
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02480, ses 1, run 1
# Subject:  02483
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02483, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02483, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02483, ses 3, run 1
# Subject:  02488
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02488, ses 2, run 1
# Subject:  02494
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02494, ses 1, run 1
# Subject:  02496
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02496, ses 1, run 1
# Subject:  02499
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02499, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02499, ses 3, run 1
# Subject:  02501
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02501, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02501, ses 3, run 1
# Subject:  02502
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02502, ses 1, run 1
# Session:  2
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02502, ses 2, run 1
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02502, ses 3, run 1
# Subject:  02507
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02507, ses 1, run 1
# Subject:  02509
# Session:  1
# Run: 2
# Filerest: []
# No file match bold filters. Subject 02509, ses 1, run 2
# Session:  3
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02509, ses 3, run 1
# Subject:  02510
# Session:  1
# Run: 1
# Filerest: []
# No file match bold filters. Subject 02510, ses 1, run 1

# %%
pd.read_csv(r'C:\Users\angel\Documents\INPD_neuroimages_CAPE\BIDS\derivatives\BOLD_ROI\sub-00003\ses-1\func\sub-00003_ses-1_task-rest_run-1_space-MNI152NLin2009cAsym_seed-SeedtoROI_tstat.txt', sep=' ')
# Out:
#      DCPutamen_space-MNI152NLin2009cAsym.nii  \
# 0                                   1.387781
# 1                                   1.611396
# 2                                   1.207885
# 3                                   1.022016
# 4                                   4.597286
# ..                                       ...
# 96                                  1.009992
# 97                                 -0.998823
# 98                                  0.325527
# 99                                  0.453840
# 100                                -0.154548
#
#      DRPutamen_space-MNI152NLin2009cAsym.nii  \
# 0                                   5.166577
# 1                                   6.130344
# 2                                  -1.510647
# 3                                   0.268063
# 4                                  -2.826788
# ..                                       ...
# 96                                  5.487061
# 97                                  2.432729
# 98                                  3.586249
# 99                                  3.442039
# 100                                 2.061085
#
#      VRPutamen_space-MNI152NLin2009cAsym.nii  \
# 0                                   5.887719
# 1                                   1.326967
# 2                                   1.113874
# 3                                   0.079695
# 4                                   0.757187
# ..                                       ...
# 96                                  0.222060
# 97                                 -0.309793
# 98                                  3.255205
# 99                                  0.043436
# 100                                 1.796433
#
#      InfVentralCaudate_space-MNI152NLin2009cAsym.nii  \
# 0                                           5.840481
# 1                                          -2.952307
# 2                                           5.220452
# 3                                          -4.039558
# 4                                           3.632276
# ..                                               ...
# 96                                         -1.309722
# 97                                          2.400158
# 98                                          6.725259
# 99                                         -2.977743
# 100                                         3.781087
#
#      SupVentralCaudate_space-MNI152NLin2009cAsym.nii  \
# 0                                          -0.686586
# 1                                          -1.518854
# 2                                           4.153809
# 3                                          -0.174929
# 4                                           7.945582
# ..                                               ...
# 96                                          1.932174
# 97                                          1.570800
# 98                                          0.307095
# 99                                         -0.752570
# 100                                        -0.428244
#
#      DorsalCaudate_space-MNI152NLin2009cAsym.nii
# 0                                       3.418319
# 1                                      -3.135082
# 2                                       5.784169
# 3                                       0.850445
# 4                                       6.143322
# ..                                           ...
# 96                                     -2.104067
# 97                                     -0.399964
# 98                                     -0.008721
# 99                                     -2.560551
# 100                                     2.625564
#
# [101 rows x 6 columns]
